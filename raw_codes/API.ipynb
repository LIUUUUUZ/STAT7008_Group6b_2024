# %%
import openai
import os
from IPython.display import display, Markdown, Latex
from langchain.llms import OpenAI
from dotenv import load_dotenv

from langchain_openai import ChatOpenAI
from langchain import PromptTemplate, LLMChain
from langchain.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    AIMessagePromptTemplate,
    HumanMessagePromptTemplate,
)
from langchain.schema import (
    AIMessage,
    HumanMessage,
    SystemMessage
)

openai.api_key  = "sk-PF3kqg0d33BqhilVyAwyrzy2NjoB0NLFIqZJCusa3mQftDy3"

# system prompt，用于告诉GPT当前的情景，不了解可以放空，没有影响。
# system prompt例如：'You are a marketing consultant, please answer the client's questions in profession style.'
system_content = ''


# 这里使用了langchain包简化与GPT的对话过程
messages = [SystemMessage(content = system_content)]


# 一轮最多对话20次，防止过长的对话。可以通过while循环条件修改。
i = 1
while i <= 20:
    chat = ChatOpenAI(
        openai_api_base="https://chatapi.littlewheat.com/v1",
        openai_api_key=openai.api_key)
    
    user_input = input()
    
   	# 输入\end结束
    if user_input == r'\end': 
        break
    # 输入\clear清空当前对话重来，重置对话场景
    if user_input == r'\clear':
        i = 1
        messages = [SystemMessage(content = system_content)] 
        continue
    
    messages.append(HumanMessage(content=user_input))
    
    response = chat(messages)
    messages.append(AIMessage(content = response.content))  # 将GPT回复加入到对话
    
    print("[GPT] Round "+ str(i))
    display(Markdown(response.content))
    
    i = i + 1

print("\n --- END ---")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import openai
#       2 import os
#       3 from IPython.display import display, Markdown, Latex
#
# ModuleNotFoundError: No module named 'openai'

# %%
# !pip install langchain
# !pip install langchain-openai
# Out:
# Collecting langchain
#   Downloading langchain-0.3.7-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from langchain) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from langchain) (1.4.39)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Downloading aiohttp-3.11.2-cp39-cp39-macosx_10_9_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.4.0,>=0.3.15 (from langchain)
#   Downloading langchain_core-0.3.18-py3-none-any.whl.metadata (6.3 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain)
#   Downloading langchain_text_splitters-0.3.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.143-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from langchain) (1.23.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from langchain) (2.28.1)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from langchain) (8.2.3)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiohappyeyeballs-2.4.3-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (21.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading frozenlist-1.5.0-cp39-cp39-macosx_10_9_x86_64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading multidict-6.1.0-cp39-cp39-macosx_10_9_x86_64.whl.metadata (5.0 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading propcache-0.2.0-cp39-cp39-macosx_10_9_x86_64.whl.metadata (7.7 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading yarl-1.17.1-cp39-cp39-macosx_10_9_x86_64.whl.metadata (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 kB 5.2 MB/s eta 0:00:00
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4.0,>=0.3.15->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting packaging<25,>=23.2 (from langchain-core<0.4.0,>=0.3.15->langchain)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.2)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.11-cp39-cp39-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 5.4 MB/s eta 0:00:00
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2022.9.24)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain) (1.1.1)
# Requirement already satisfied: anyio in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (3.5.0)
# Requirement already satisfied: httpcore==1.* in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.6)
# Requirement already satisfied: sniffio in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Downloading langchain-0.3.7-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 8.2 MB/s eta 0:00:0000:0100:01
# Downloading aiohttp-3.11.2-cp39-cp39-macosx_10_9_x86_64.whl (466 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.0/467.0 kB 10.0 MB/s eta 0:00:00a 0:00:01
# Downloading langchain_core-0.3.18-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.3/409.3 kB 9.1 MB/s eta 0:00:00:00:01
# Downloading langchain_text_splitters-0.3.2-py3-none-any.whl (25 kB)
# Downloading langsmith-0.1.143-py3-none-any.whl (306 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.0/307.0 kB 9.5 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.4.3-py3-none-any.whl (14 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading frozenlist-1.5.0-cp39-cp39-macosx_10_9_x86_64.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 2.9 MB/s eta 0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading multidict-6.1.0-cp39-cp39-macosx_10_9_x86_64.whl (29 kB)
# Downloading orjson-3.10.11-cp39-cp39-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (266 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.1/266.1 kB 9.3 MB/s eta 0:00:00
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 7.6 MB/s eta 0:00:00
# Downloading propcache-0.2.0-cp39-cp39-macosx_10_9_x86_64.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 5.2 MB/s eta 0:00:00
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.9 MB/s eta 0:00:00
# Downloading yarl-1.17.1-cp39-cp39-macosx_10_9_x86_64.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.2/94.2 kB 7.7 MB/s eta 0:00:00
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Installing collected packages: propcache, packaging, orjson, multidict, jsonpointer, frozenlist, aiohappyeyeballs, yarl, requests-toolbelt, jsonpatch, aiosignal, langsmith, aiohttp, langchain-core, langchain-text-splitters, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.0
#     Uninstalling packaging-23.0:
#       Successfully uninstalled packaging-23.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.3.3 requires pyqt5<5.16, which is not installed.
# spyder 5.3.3 requires pyqtwebengine<5.16, which is not installed.
# distributed 2022.7.0 requires tornado<6.2,>=6.0.3, but you have tornado 6.2 which is incompatible.
# spyder 5.3.3 requires ipython<8.0.0,>=7.31.1, but you have ipython 8.11.0 which is incompatible.
# spyder 5.3.3 requires qdarkstyle<3.1.0,>=3.0.2, but you have qdarkstyle 3.1 which is incompatible.
# spyder-kernels 2.3.3 requires ipython<8,>=7.31.1; python_version >= "3", but you have ipython 8.11.0 which is incompatible.
# spyder-kernels 2.3.3 requires jupyter-client<8,>=7.3.4; python_version >= "3", but you have jupyter-client 8.0.3 which is incompatible.
# streamlit 1.31.0 requires packaging<24,>=16.8, but you have packaging 24.2 which is incompatible.
# Successfully installed aiohappyeyeballs-2.4.3 aiohttp-3.11.2 aiosignal-1.3.1 frozenlist-1.5.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.7 langchain-core-0.3.18 langchain-text-splitters-0.3.2 langsmith-0.1.143 multidict-6.1.0 orjson-3.10.11 packaging-21.3 propcache-0.2.0 requests-toolbelt-1.0.0 yarl-1.17.1
#
# [notice] A new release of pip is available: 23.3.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Collecting langchain-openai
#   Downloading langchain_openai-0.2.8-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.17 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from langchain-openai) (0.3.18)
# Requirement already satisfied: openai<2.0.0,>=1.54.0 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from langchain-openai) (1.54.4)
# Collecting tiktoken<1,>=0.7 (from langchain-openai)
#   Downloading tiktoken-0.8.0-cp39-cp39-macosx_10_9_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: PyYAML>=5.3 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.17->langchain-openai) (6.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.17->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.17->langchain-openai) (0.1.143)
# Collecting packaging<25,>=23.2 (from langchain-core<0.4.0,>=0.3.17->langchain-openai)
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.17->langchain-openai) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.17->langchain-openai) (8.2.3)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.17->langchain-openai) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (3.5.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (0.7.1)
# Requirement already satisfied: sniffio in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (1.2.0)
# Requirement already satisfied: tqdm>4 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (4.64.1)
# Requirement already satisfied: regex>=2022.1.18 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2022.7.9)
# Requirement already satisfied: requests>=2.26.0 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.28.1)
# Requirement already satisfied: idna>=2.8 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.54.0->langchain-openai) (3.3)
# Requirement already satisfied: certifi in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.54.0->langchain-openai) (2022.9.24)
# Requirement already satisfied: httpcore==1.* in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.54.0->langchain-openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.54.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.17->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.17->langchain-openai) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.17->langchain-openai) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.17->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.17->langchain-openai) (2.23.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/liuzhixian/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (1.26.20)
# Downloading langchain_openai-0.2.8-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.5 MB/s eta 0:00:00
# Downloading tiktoken-0.8.0-cp39-cp39-macosx_10_9_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 6.8 MB/s eta 0:00:00ta 0:00:01
# Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Installing collected packages: packaging, tiktoken, langchain-openai
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.3.3 requires pyqt5<5.16, which is not installed.
# spyder 5.3.3 requires pyqtwebengine<5.16, which is not installed.
# distributed 2022.7.0 requires tornado<6.2,>=6.0.3, but you have tornado 6.2 which is incompatible.
# spyder 5.3.3 requires ipython<8.0.0,>=7.31.1, but you have ipython 8.11.0 which is incompatible.
# spyder 5.3.3 requires qdarkstyle<3.1.0,>=3.0.2, but you have qdarkstyle 3.1 which is incompatible.
# spyder-kernels 2.3.3 requires ipython<8,>=7.31.1; python_version >= "3", but you have ipython 8.11.0 which is incompatible.
# spyder-kernels 2.3.3 requires jupyter-client<8,>=7.3.4; python_version >= "3", but you have jupyter-client 8.0.3 which is incompatible.
# streamlit 1.31.0 requires packaging<24,>=16.8, but you have packaging 24.2 which is incompatible.
# Successfully installed langchain-openai-0.2.8 packaging-24.2 tiktoken-0.8.0
#
# [notice] A new release of pip is available: 23.3.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import openai
from langchain_openai import ChatOpenAI
from langchain.schema import (
    AIMessage,
    HumanMessage,
    SystemMessage
)
system_content = '你是一位专业的贷款顾问chatbot,正在为STAT7008第6组服务,回答客户的问题时请保持专业。'
messages = [SystemMessage(content = system_content)]
openai.api_key  = "sk-PF3kqg0d33BqhilVyAwyrzy2NjoB0NLFIqZJCusa3mQftDy3"
chat = ChatOpenAI(
        openai_api_base="https://chatapi.littlewheat.com/v1",
        openai_api_key=openai.api_key)
    
user_input = "介绍自己"

messages.append(HumanMessage(content=user_input))
    
response = chat(messages)
messages.append(AIMessage(content = response.content))
print(response)
# Out:
# content='您好，我是您的贷款顾问chatbot，专门为您提供有关贷款的专业信息和建议。无论您是想了解个人贷款、住房贷款还是商业贷款，我都可以帮助您解答相关问题，提供贷款申请的指导，以及帮助您比较不同的贷款产品。请随时告诉我您的需求，我将竭诚为您服务！' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 77, 'prompt_tokens': 42, 'total_tokens': 119, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d54531d9eb', 'finish_reason': 'stop', 'logprobs': None} id='run-c6591c70-71f4-482d-be45-0b866e657a5a-0' usage_metadata={'input_tokens': 42, 'output_tokens': 77, 'total_tokens': 119, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}}

# %%
from utilities import ChatBot

system_content = '你是一位专业的贷款顾问chatbot,正在为STAT7008第6组服务,回答客户的问题时请保持专业。'

cb = ChatBot(api_key="sk-PF3kqg0d33BqhilVyAwyrzy2NjoB0NLFIqZJCusa3mQftDy3", init_prompt=system_content)

print(cb("你好,介绍你自己"))
print("******************************")
print(cb("简单介绍一下金融风险相关的知识"))
print("******************************")
print(cb("提供一些可以学习信贷风险的网站"))
print("******************************")
# Out:
# /Users/liuzhixian/Documents/GitHub/STAT7008_Group6b_2024/utilities/chatbot.py:18: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = self.chat(self.messages)
# 你好！我是一个专业的贷款顾问聊天机器人，专门为您提供有关贷款的咨询和帮助。无论您对个人贷款、房屋贷款、商业贷款或其他金融产品有任何疑问，我都可以为您提供信息和建议。请告诉我您的具体需求或问题，我会尽力帮助您！
# ******************************
# 金融风险是指由于市场波动、信用违约或其他因素导致金融投资或交易损失的可能性。以下是金融风险的一些主要类型：
#
# 1. **市场风险**：这是由于市场价格波动（例如股票、债券、外汇等）引起的风险。市场风险通常分为系统性风险（影响整个市场）和非系统性风险（影响特定资产）。
#
# 2. **信用风险**：这是借款人或对手方未能履行合约义务（如还款）的风险。信用风险通常通过评估借款人的信用评级来管理。
#
# 3. **流动性风险**：这指的是在需要时无法以合理价格出售资产的风险。流动性风险可能导致投资者无法及时变现资产。
#
# 4. **利率风险**：利率的变动会影响固定收益投资（如债券）的价值。利率上升通常会导致债券价格下降，反之亦然。
#
# 5. **操作风险**：这是由于内部流程、人员或系统的失败导致的风险，包括技术故障、欺诈或合规问题。
#
# 6. **法律和合规风险**：涉及法律法规变化或违反法律法规导致的损失风险。
#
# 了解这些风险有助于投资者和金融机构制定风险管理策略，以降低潜在的损失。如果您有特定的问题或需要更详细的信息，欢迎随时询问！
# ******************************
# 以下是一些可以学习信贷风险的资源和网站：
#
# 1. **Coursera**：提供许多关于金融和信贷风险管理的在线课程，来自知名大学和机构的讲师教授。您可以搜索特定课程，例如“信贷风险管理”或“金融风险管理”。
#
#    网站链接：[Coursera](https://www.coursera.org)
#
# 2. **edX**：同样提供来自世界各地大学的在线课程，其中包括金融风险和信贷风险相关的内容。
#
#    网站链接：[edX](https://www.edx.org)
#
# 3. **Investopedia**：这是一个非常全面的金融教育网站，提供信贷风险相关的文章、定义和教程。
#
#    网站链接：[Investopedia](https://www.investopedia.com)
#
# 4. **风险管理协会（Risk Management Association, RMA）**：该协会提供关于信贷风险管理的资源和培训，适合金融专业人士。
#
#    网站链接：[RMA](https://www.rmahq.org)
#
# 5. **国际金融公司（International Finance Corporation, IFC）**：提供关于信贷风险管理的指南和案例研究，特别关注发展中市场。
#
#    网站链接：[IFC](https://www.ifc.org)
#
# 6. **金融风险管理协会（GARP）**：提供相关认证和资源，帮助专业人士提高其在风险管理领域的知识。
#
#    网站链接：[GARP](https://www.garp.org)
#
# 7. **学术期刊**：如《Journal of Credit Risk》，可以通过大学图书馆或在线数据库访问，提供关于信贷风险的最新研究和论文。
#
# 这些资源可以帮助您深入了解信贷风险的概念、管理策略和最新趋势。希望对您有所帮助！如果您有其他问题，请随时询问。
# ******************************
